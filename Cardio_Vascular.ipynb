# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn

# %%
df = pd.read_csv(r"C:\Users\SHUVO\Downloads\cardio_train.csv\cardio_train.csv",sep=";")

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
x = df.drop(['cardio'],axis=1)

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y = df['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
xtrain
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 58105  82903  18365       1     158    66.0    110     70            1     1
# 22589  32272  17440       2     188    86.0    120     80            1     1
# 4183    5906  17469       2     165    63.0    120     80            1     1
# 18670  26660  17389       1     172   105.0    140     90            1     1
# 41299  59019  21795       1     164    70.0    110     70            2     2
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 49100  70099  21289       2     175    78.0    120     80            1     1
# 20609  29410  19116       1     164    68.0    120     80            1     1
# 21440  30634  18049       2     178    82.0    120     80            1     1
# 50057  71447  21957       1     169    77.0    120     80            1     1
# 5192    7386  20671       1     174    65.0    160     90            2     2
#
#        smoke  alco  active
# ...

# %%
model = SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model.score(xtest,ytest)
# Out:
# 0.5986285714285714

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
seaborn.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
seaborn.countplot(x='gender',hue='cardio',data=df,palette='colorblind',edgecolor='black')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['yr'] = (df['age']/365).round(0)

# %%
df['yr']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr, Length: 70000, dtype: float64

# %%
seaborn.countplot(x='yr',hue='cardio',data=df,palette='colorblind',edgecolor='black')
# Out:
# <Axes: xlabel='yr', ylabel='count'>

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
df = df.drop(['yr'],axis=1)

# %%
x = df.drop(['cardio'],axis=1)

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y = df['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
xtrain
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 23561  33670  16136       2     169    71.0    100     80            1     1
# 34858  49789  14615       1     158    69.0    140     80            2     1
# 54953  78398  20507       1     164    65.0    120     80            1     1
# 59230  84572  16720       1     153    53.0    100     60            1     1
# 1730    2449  21050       1     159    71.0    140     90            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 49100  70099  21289       2     175    78.0    120     80            1     1
# 20609  29410  19116       1     164    68.0    120     80            1     1
# 21440  30634  18049       2     178    82.0    120     80            1     1
# 50057  71447  21957       1     169    77.0    120     80            1     1
# 5192    7386  20671       1     174    65.0    160     90            2     2
#
#        smoke  alco  active
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rcfc = RandomForestClassifier()

# %%
Rcfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
Rcfc.score(xtest,ytest)
# Out:
# 0.7252380952380952

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dtc = DecisionTreeClassifier()

# %%
Dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Dtc.score(xtest,ytest)
# Out:
# 0.6355238095238095

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
LR.score(xtest,ytest)
# Out:
# 0.11811647140913717

# %%
from sklearn.linear_model import LogisticRegression

# %%
LoR = LogisticRegression()

# %%
LoR.fit(xtrain,ytrain)
# Out:
# C:\Users\SHUVO\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LoR.score(xtest,ytest)
# Out:
# 0.6958095238095238

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
knn.score(xtest,ytest)
# Out:
# 0.5554761904761905
