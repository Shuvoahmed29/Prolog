# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn

# %%
df = pd.read_csv(r"C:\Users\SHUVO\Desktop\CSE-(4,1) Exam\Artificial Intelligence\Lab\Prolog Code\Prolog\cardio_train.csv\cardio_train.csv",sep=";")

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df = df.drop(['id'],axis=1)

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
x = df.drop(['cardio'],axis=1)

# %%
x
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y = df['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.20,random_state=1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 57050  20275       1     156    73.0    120     80            2     1      0
# 66119  19628       2     172    78.0    150    100            1     1      1
# 2762   22066       1     157    60.0    100     60            2     1      0
# 6182   19626       2     168    75.0    120     80            1     1      0
# 35804  21884       2     166    64.0    150     90            2     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100  21289       2     175    78.0    120     80            1     1      0
# 20609  19116       1     164    68.0    120     80            1     1      0
# 21440  18049       2     178    82.0    120     80            1     1      0
# 50057  21957       1     169    77.0    120     80            1     1      0
# 5192   20671       1     174    65.0    160     90            2     2      0
#
#        alco  active
# 57050     0       1
# ...

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
accuracy = model.score(xtest,ytest)
print("SVM Model Accuracy: ",accuracy)
# Out:
# SVM Model Accuracy:  0.6027142857142858

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict(xtest)

# %%
cm = confusion_matrix(ytest, y_pred)

# %%
plt.figure(figsize=(6, 4))
seaborn.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'], yticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
accuracy = model.score(xtest,ytest)
print("Decision tree model accuracy: ",accuracy)
# Out:
# Decision tree model accuracy:  0.6325714285714286

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Diseases','Cardio Vascular'],yticklabels=['No Diseases','Cardio Vascular'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
accuracy = model.score(xtest,ytest)
print("Random Forest model accuracy: ",accuracy)
# Out:
# Random Forest model accuracy:  0.7188571428571429

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=["No Diseases","Cardio Diseases"],yticklabels=["No Diseases","Cardio Diseases"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel('True')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
accuracy = model.score(xtest,ytest)
print("Linear Regression Accuracy: ",accuracy)
# Out:
# Linear Regression Accuracy:  0.11862778780588734

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pre = model.predict(xtest)

# %%
mae = mean_absolute_error(ytest, y_pred)
mse = mean_squared_error(ytest, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(ytest, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.44120239249908183
# Mean Squared Error: 0.2203120746139883
# Root Mean Squared Error: 0.46937413074645296
# R-squared: 0.11862778780588734

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# C:\Users\SHUVO\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
accuracy = model.score(xtest,ytest)
print("Logistic Regression model accuracy : ",accuracy)
# Out:
# Logistic Regression model accuracy :  0.7046428571428571

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6, 4))
seaborn.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'], yticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
accuracy = model.score(xtest,ytest)
print("K Nearest Neighbors model accuracy: ",accuracy)
# Out:
# K Nearest Neighbors model accuracy:  0.6861428571428572

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6, 4))
seaborn.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'], yticklabels=['No Cardiovascular Disease', 'Cardiovascular Disease'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
