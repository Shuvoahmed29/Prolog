# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn

# %%
df = pd.read_csv('Stroke_Dataset.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df = df.drop(['id'],axis=1)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
missing = 28.893237
df['bmi']=df.bmi.fillna(missing)

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df['gender'] = df['gender'].replace({'Male':1,'Female':2,'Other':3})

# %%
df['ever_married'] = df['ever_married'].replace({'Yes':0,'No':1})

# %%
df = df.drop(['work_type'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 df = df.drop(['work_type'],axis=1)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df = df.drop(['Residence_type'],axis=1)

# %%
df['smoking_status'] = df['smoking_status'].replace({'Unknown':0.5,'smokes':1,'never smoked':0,'formerly smoked':0.7})

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  \
# 0          1  67.0             0              1             0
# 1          2  61.0             0              0             0
# 2          1  80.0             0              1             0
# 3          2  49.0             0              0             0
# 4          2  79.0             1              0             0
# ...      ...   ...           ...            ...           ...
# 5105       2  80.0             1              0             0
# 5106       2  81.0             0              0             0
# 5107       2  35.0             0              0             0
# 5108       1  51.0             0              0             0
# 5109       2  44.0             0              0             0
#
#       avg_glucose_level        bmi  smoking_status  stroke
# 0                228.69  36.600000             0.7       1
# 1                202.21  28.893237             0.0       1
# ...

# %%
x = df.drop(['stroke'],axis=1)

# %%
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  \
# 0          1  67.0             0              1             0
# 1          2  61.0             0              0             0
# 2          1  80.0             0              1             0
# 3          2  49.0             0              0             0
# 4          2  79.0             1              0             0
# ...      ...   ...           ...            ...           ...
# 5105       2  80.0             1              0             0
# 5106       2  81.0             0              0             0
# 5107       2  35.0             0              0             0
# 5108       1  51.0             0              0             0
# 5109       2  44.0             0              0             0
#
#       avg_glucose_level        bmi  smoking_status
# 0                228.69  36.600000             0.7
# 1                202.21  28.893237             0.0
# 2                105.92  32.500000             0.0
# ...

# %%
y = df['stroke']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.20,random_state=1)

# %%
xtrain
# Out:
#       gender   age  hypertension  heart_disease  ever_married  \
# 4152       1  55.0             0              0             0
# 4051       1  55.0             0              0             0
# 5076       2  34.0             0              0             0
# 874        1  80.0             0              0             0
# 3534       2  61.0             0              0             0
# ...      ...   ...           ...            ...           ...
# 2895       1  46.0             0              0             0
# 2763       2  45.0             0              0             0
# 905        2  31.0             0              0             0
# 3980       2  45.0             0              0             0
# 235        2  68.0             0              0             0
#
#       avg_glucose_level   bmi  smoking_status
# 4152              73.57  28.0             1.0
# 4051             231.15  22.3             0.0
# 5076             174.37  23.0             0.0
# ...

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
accuracy = model.score(xtest,ytest)
print("SVM Accuracy : ",accuracy)
# Out:
# SVM Accuracy :  0.9412915851272016

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Stroke','Stroke'],yticklabels=['No Stroke','Stroke'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('SVM Confusion Matrix')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
accuracy = model.score(xtest,ytest)
print("Random Forest accuracy: ",accuracy)
# Out:
# Random Forest accuracy:  0.9383561643835616

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pre = model.predict(xtest)

# %%
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Stroke','Stroke'],yticklabels=['No Stroke','Stroke'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Random Forest Confusion Matrix')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
accuracy = model.score(xtest,ytest)
print("Decision Tree: ",accuracy)
# Out:
# Decision Tree:  0.9158512720156555

# %%
from sklearn.metrics import confusion_matrix
y_pre = model.predict(xtest)
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Stroke','Stroke'],yticklabels=['No Stroke','Stroke'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Decision Tree Confusion Matrix')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
accuracy = model.score(xtest,ytest)
print('Linear Regression Accuracy: ',accuracy)
# Out:
# Linear Regression Accuracy:  0.08541761118281022

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
y_pre = model.predict(xtest)
mae = mean_absolute_error(ytest,y_pre)
msa = mean_squared_error(ytest,y_pre)
rmse = np.sqrt(mse)
r2 = r2_score(ytest,y_pre)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
accuracy = model.score(xtest,ytest)
print('Logistic regression Accuracy: ',accuracy)
# Out:
# Logistic regression Accuracy:  0.9412915851272016

# %%
from

# %%
from sklearn.metrics import confusion_matrix
y_pre = model.predict(xtest)
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Stroke','Stroke'],yticklabels=['No Stroke','Stroke'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Logistic Regression Tree Confusion Matrix')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
accuracy = model.score(xtest,ytest)
print('KNN Accuracy: ',accuracy)
# Out:
# KNN Accuracy:  0.9344422700587084

# %%
from sklearn.metrics import confusion_matrix
y_pre = model.predict(xtest)
cm = confusion_matrix(ytest,y_pre)

# %%
plt.figure(figsize=(6,4))
seaborn.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['No Stroke','Stroke'],yticklabels=['No Stroke','Stroke'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('KNN Confusion Matrix')
plt.show()
